# %%
import os
os.chdir("/content/gdrive/My Drive/METIS_IDS_PROJECT_01")
# !ls
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-dd368a425479> in <module>()
#       1 import os
# ----> 2 os.chdir("/content/gdrive/My Drive/METIS_IDS_PROJECT_01")
#       3 get_ipython().system('ls')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/gdrive/My Drive/METIS_IDS_PROJECT_01'

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd gdrive/My Drive/METIS_IDS_PROJECT_01
# !ls
# Out:
# /content/gdrive/My Drive/METIS_IDS_PROJECT_01
# demonstrator.ipynb	   PredictiveAnalytics_v2.ipynb  symbols_dict_01.csv
# get_to_git.ipynb	   quad_probs.txt		 symbols_dict_02.csv
# PredictiveAnalytics.ipynb  README.md

# %%
# !ls
# Out:
# gdrive	sample_data

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/gdrive/My Drive/METIS_IDS_PROJECT_01/.git/

# %%
# !git clone https://github.com/jefferygao1984/METIS_IDS_PROJECT.git
# !git remote set-url origin https://jefferygao1984:lightverse01@github.com/jefferygao1984/METIS_IDS_PROJECT.git
# !git remote -v
# Out:
# origin	https://jefferygao1984:lightverse01@github.com/jefferygao1984/METIS_IDS_PROJECT.git (fetch)
# origin	https://jefferygao1984:lightverse01@github.com/jefferygao1984/METIS_IDS_PROJECT.git (push)

# %%
# !git config --global user.email 'jeffrey.gao@kbs.edu.au'
# !git config --global user.name 'jefferygao1984'

# %%
# !git pull origin master --allow-unrelated-histories
# Out:
# From https://github.com/jefferygao1984/METIS_IDS_PROJECT
#  * branch            master     -> FETCH_HEAD
# Already up to date.

# %%
from datetime import datetime
now = datetime.now()
dt_string = now.strftime("%d/%m/%Y %H:%M:%S")
commit_msg = 'Latest commit at: ' + dt_string

# !git add .
# !git commit -m commit_msg
# Out:
# [master 3dddcd3] commit_msg
#  3 files changed, 21 insertions(+), 2 deletions(-)
#  rewrite PredictiveAnalytics_v2.ipynb (86%)
#  rewrite get_to_git.ipynb (94%)
#  create mode 100644 quad_probs.txt

# %%
# !git push origin master
# Out:
# Counting objects: 5, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 5.34 KiB | 390.00 KiB/s, done.
# Total 5 (delta 3), reused 0 (delta 0)
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To https://github.com/jefferygao1984/METIS_IDS_PROJECT.git
#    441a1b4..3dddcd3  master -> master

# %% [markdown]
# # Hard reset current commit branch
#
# https://stackoverflow.com/questions/13716658/how-to-delete-all-commit-history-in-github
#
# Deleting the .git folder may cause problems in your git repository. If you want to delete all your commit history but keep the code in its current state, it is very safe to do it as in the following:

# %%
# checkout
# !git checkout --orphan latest_branch
# Out:
# M	get_to_git.ipynb
# Switched to a new branch 'latest_branch'

# %%
# Add all the files
# !git add -A

# %%
# authentication
# !git config --global user.email 'jeffrey.gao@kbs.edu.au'
# !git config --global user.name 'jefferygao1984'

# Commit the changes
# !git commit -am "hard reset"
# Out:
# [latest_branch (root-commit) 771ae5b] hard reset
#  6 files changed, 160 insertions(+)
#  create mode 100644 PredictiveAnalytics.ipynb
#  create mode 100644 README.md
#  create mode 100644 demonstrator.ipynb
#  create mode 100644 get_to_git.ipynb
#  create mode 100644 symbols_dict_01.csv
#  create mode 100644 symbols_dict_02.csv

# %%
# delete the branch
# !git branch -D master
# Out:
# Deleted branch master (was 22b3f95).

# %%
# Rename the current branch to master
# !git branch -m master

# %%
# force update your repository
# PS: this will not keep your old commit history around
# !git push -f origin master
# Out:
# Counting objects: 8, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (8/8), done.
# Writing objects: 100% (8/8), 158.16 KiB | 3.77 MiB/s, done.
# Total 8 (delta 0), reused 0 (delta 0)
# To https://github.com/jefferygao1984/METIS_IDS_PROJECT.git
#  + dd16885...771ae5b master -> master (forced update)
